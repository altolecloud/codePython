# %% [markdown]
# Nuestro primer codigo - Hola mundo

# %%
print("Hola mundo")
# Out:
# Hola mundo

# %% [markdown]
# Multiples hola mundo

# %%
print("Hola mundo")
print("Hola mundo")
print("Hola mundo")
print("Hola mundo")
# Out:
# Hola mundo
# Hola mundo
# Hola mundo
# Hola mundo

# %% [markdown]
# verion python

# %%
# !python --version
# Out:
# Python 3.10.12
