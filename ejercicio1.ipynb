# %%
nombre = "Alvaro"
apellido = "Torres Leon"
edad = 46
estatura = 1,70

print("Nombre", nombre, apellido,
      "Edad", edad, "Estatura", estatura)
# Out:
# Nombre Alvaro Torres Leon Edad 46 Estatura (1, 70)
