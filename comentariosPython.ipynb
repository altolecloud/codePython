# %%
#La siguiente liea representa el salario mensual de una persona

salario = 1000

"""Dividiremos el salario entre 2, para repartirlo entre los integrantes
de  la familia y mostraremos el resultado por pantalla"""

print(salario/2)
# Out:
# 500.0
